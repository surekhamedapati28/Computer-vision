# %%
# prompt: cannot create extraction directory: /content/drive/MyDrive/Colab\ Notebooks/dataset
#            No such file or directory

import os

# Create the directory if it doesn't exist
directory_path = '/content/drive/MyDrive/Colab Notebooks/dataset/archive.zip'
if not os.path.exists(directory_path):
    os.makedirs(directory_path)
    print(f"Directory '{directory_path}' created successfully.")
else:
    print(f"Directory '{directory_path}' already exists.")
# Out:
# Directory '/content/drive/MyDrive/Colab Notebooks/dataset/archive.zip' already exists.

# %%
# !pip install grad-cam
# Out:
# Collecting grad-cam
#   Downloading grad-cam-1.5.4.tar.gz (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 48.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from grad-cam) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from grad-cam) (11.0.0)
# Requirement already satisfied: torch>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from grad-cam) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.8.2 in /usr/local/lib/python3.10/dist-packages (from grad-cam) (0.20.1+cu121)
# Collecting ttach (from grad-cam)
#   Downloading ttach-0.0.3-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from grad-cam) (4.67.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from grad-cam) (4.10.0.84)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from grad-cam) (3.8.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from grad-cam) (1.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->grad-cam) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->grad-cam) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->grad-cam) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->grad-cam) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->grad-cam) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->grad-cam) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.7.1->grad-cam) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam) (2.8.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->grad-cam) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->grad-cam) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->grad-cam) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->grad-cam) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7.1->grad-cam) (3.0.2)
# Downloading ttach-0.0.3-py3-none-any.whl (9.8 kB)
# Building wheels for collected packages: grad-cam
#   Building wheel for grad-cam (pyproject.toml) ... done
#   Created wheel for grad-cam: filename=grad_cam-1.5.4-py3-none-any.whl size=39588 sha256=eab63d3b345f1b60e20dc6e84dce07803c423fbaa64282ce1d08d7a975fc243d
#   Stored in directory: /root/.cache/pip/wheels/50/b0/82/1f97b5348c7fe9f0ce0ba18497202cafa5dec4562bd5292680
# Successfully built grad-cam
# Installing collected packages: ttach, grad-cam
# Successfully installed grad-cam-1.5.4 ttach-0.0.3

# %%
import os
# Check if the directory exists
dataset_dir = "/content/drive/MyDrive/Colab Notebooks/dataset/archive.zip"
# !unzip '/content/drive/MyDrive/Colab Notebooks/dataset/archive.zip' -d '/content/drive/MyDrive/Colab Notebooks/dataset/'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44260_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44261_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44261_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44262_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44262_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44263_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44263_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44264_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44264_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44265_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44265_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44267_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44267_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44268_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44268_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44275_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44275_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44278_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44278_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44280_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44280_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44281_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44281_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44282_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44282_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44284_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44284_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44285_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44285_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44287_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44287_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44298_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44298_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44306_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44306_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44308_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44308_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44309_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44309_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44317_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44317_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44323_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44323_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44325_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44325_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44327_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44327_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44328_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44328_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44330_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44330_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44331_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44331_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44334_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44334_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44337_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44337_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44338_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44338_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44339_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44339_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44343_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44343_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44347_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44347_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44348_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44348_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44349_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/44349_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4434_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4434_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4436_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4436_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4437_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4437_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4443_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4443_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4444_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4444_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4448_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4448_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/444_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/444_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4450_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4450_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4452_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4452_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/445_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/445_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4460_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4460_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4462_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4462_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4464_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4464_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4466_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4466_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/446_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/446_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4470_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4470_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4471_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4471_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4472_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4472_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4475_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4475_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4478_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4478_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4479_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4479_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4482_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4482_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4484_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4484_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4485_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4485_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4488_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4488_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/448_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/448_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4490_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4490_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4491_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4491_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4495_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4495_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4496_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4496_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4497_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4497_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4498_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4498_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4499_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4499_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/449_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/449_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4506_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4506_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4508_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4508_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4513_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4513_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4514_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4514_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4518_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4518_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4519_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4519_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/451_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/451_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4523_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4523_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4524_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4524_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4526_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4526_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4527_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4527_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4531_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4531_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4532_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4532_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4533_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4533_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4534_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4534_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4535_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4535_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4538_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4538_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4544_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4544_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4545_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4545_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4548_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4548_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4550_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4550_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4551_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4551_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4555_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4555_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4558_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4558_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4559_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4559_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4561_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4561_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4563_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4563_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4567_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4567_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4568_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4568_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4569_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4569_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/456_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/456_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4570_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4570_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4571_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4571_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/457_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/457_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4581_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4581_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4582_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4582_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4583_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4583_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4584_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4584_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/458_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/458_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4593_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4593_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4594_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4594_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4595_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4595_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4599_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4599_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4601_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4601_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4602_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4602_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4604_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4604_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4609_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4609_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/460_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/460_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4614_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4614_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4615_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4615_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4620_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4620_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4624_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4624_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4626_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4626_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4629_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4629_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4631_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4631_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4632_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4632_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4633_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4633_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4641_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4641_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4642_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4642_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4649_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4649_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4652_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4652_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4657_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4657_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4658_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4658_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4659_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4659_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/465_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/465_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4665_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4665_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/466_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/466_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4672_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4672_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4674_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4674_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4676_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4676_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/467_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/467_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4685_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4685_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4687_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4687_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4688_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4688_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4689_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4689_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4690_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4690_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4693_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4693_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4694_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4694_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4695_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4695_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4696_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4696_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4697_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4697_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4698_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4698_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/46_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/46_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4702_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4702_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4703_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4703_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4710_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4710_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4711_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4711_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4713_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4713_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4714_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4714_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4716_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4716_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4721_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4721_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4722_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4722_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4723_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4723_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4724_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4724_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4727_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4727_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/472_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/472_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4731_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4731_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4732_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4732_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4734_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4734_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4735_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4735_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4738_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4738_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4739_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4739_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/473_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/473_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4740_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4740_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4741_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4741_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4750_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4750_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4754_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4754_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4755_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4755_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4757_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4757_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4764_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4764_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4765_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4765_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4766_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4766_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4769_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4769_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4771_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4771_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4773_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4773_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4776_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4776_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4779_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4779_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4780_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4780_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4781_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4781_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4784_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4784_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4788_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4788_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4793_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4793_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4795_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4795_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4798_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4798_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4799_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4799_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/47_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/47_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4800_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4800_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4802_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4802_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/4804_left.jpeg
# ...
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9873_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9873_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9874_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9874_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9875_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9875_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9876_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9876_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9878_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9878_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9879_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9879_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/987_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/987_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9884_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9884_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9889_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9889_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9893_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9893_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9894_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9894_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9895_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9895_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9896_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9896_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9897_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9897_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9899_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9899_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9900_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9900_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9906_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9906_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9907_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9907_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/990_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/990_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9913_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9913_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9914_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9914_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9919_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9919_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9925_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9925_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9927_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9927_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9929_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9929_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/992_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/992_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9930_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9930_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9933_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9933_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9934_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9934_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9937_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9937_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9939_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9939_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9940_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9940_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9942_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9942_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9945_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9945_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9947_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9947_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9948_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9948_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9949_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9949_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/994_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/994_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9951_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9951_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9952_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9952_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9957_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9957_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9958_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9958_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9959_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9959_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9961_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9961_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9963_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9963_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9964_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9964_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9965_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9965_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9966_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9966_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9967_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9967_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9971_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9971_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9972_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9972_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9975_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9975_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9976_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9976_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9977_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9977_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9979_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9979_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/997_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/997_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9980_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9980_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9984_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9984_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/998_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/998_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9992_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9992_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9993_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9993_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9996_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9996_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9998_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9998_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9999_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/9999_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/99_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/99_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/trainLabels.csv
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/trainLabels_cropped.csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import copy
import os
import random
import sys
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image
from sklearn.metrics import cohen_kappa_score, precision_score, recall_score, accuracy_score
from torch.utils.data import Dataset, DataLoader
from torchvision import models, transforms
from torchvision.transforms.functional import to_pil_image
from tqdm import tqdm
import matplotlib.pyplot as plt
from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.image import show_cam_on_image

# Hyper Parameters
batch_size = 32
num_classes = 5  # 5 DR levels
learning_rate = 0.0001
num_epochs = 15

class RetinopathyDataset(Dataset):
    def __init__(self, ann_file, image_dir, transform=None, test=False):
        self.ann_file = ann_file
        self.image_dir = image_dir
        self.transform = transform
        self.test = test
        self.data = self.load_data()

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        data = self.data[index]
        img = Image.open(data['img_path']).convert('RGB')
        if self.transform:
            img = self.transform(img)

        if not self.test:
            label = torch.tensor(data['dr_level'], dtype=torch.int64)
            return img, label
        else:
            return img, data['img_id']

    def load_data(self):
        df = pd.read_csv(self.ann_file)
        data = []
        for _, row in df.iterrows():
            file_info = dict()
            file_info['img_path'] = os.path.join(self.image_dir, row['img_path'])
            file_info['img_id'] = row['img_path']
            if not self.test:
                file_info['dr_level'] = int(row['patient_DR_Level'])
            data.append(file_info)
        return data

transform_train = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.RandomCrop((224, 224)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

transform_test = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

class MyModel(nn.Module):
    def __init__(self, num_classes=5, backbone='resnet18'):
        super().__init__()
        if backbone == 'resnet18':
            self.backbone = models.resnet18(pretrained=True)
            state_dict = torch.load('/content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/pretrained_DR_resize/pretrained/resnet18.pth', map_location='cpu')
        elif backbone == 'resnet34':
            self.backbone = models.resnet34(pretrained=True)
            state_dict = torch.load('/content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/pretrained_DR_resize/pretrained/resnet34.pth', map_location='cpu')
        elif backbone == 'vgg':
            self.backbone = models.vgg16(pretrained=True)
            self.backbone.avgpool = nn.AdaptiveAvgPool2d((1, 1))
            state_dict = torch.load('/content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/pretrained_DR_resize/pretrained/vgg16.pth', map_location='cpu')
        elif backbone == 'efficientnet':
            self.backbone = models.efficientnet_b0(pretrained=True)
            state_dict = torch.load('/content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/pretrained_DR_resize/pretrained/efficientnet_b0.pth', map_location='cpu')
        elif backbone == 'densenet':
            self.backbone = models.densenet121(pretrained=True)
            state_dict = torch.load('/content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/pretrained_DR_resize/pretrained/densenet121.pth', map_location='cpu')
        else:
            raise ValueError("Unsupported backbone model")

        info = self.backbone.load_state_dict(state_dict, strict=False)
        print('missing keys:', info[0])  # Missing fc or classifier layer is normal
        print('unexpected keys:', info[1])

        if hasattr(self.backbone, 'fc'):
            self.backbone.fc = nn.Linear(self.backbone.fc.in_features, num_classes)
        elif hasattr(self.backbone, 'classifier'):
            self.backbone.classifier[-1] = nn.Linear(self.backbone.classifier[-1].in_features, num_classes)

    def forward(self, x):
        return self.backbone(x)

if __name__ == '__main__':
    backbone = 'efficientnet'  # Change to 'resnet34', 'vgg', 'efficientnet', or 'densenet'
    model = MyModel(num_classes=num_classes, backbone=backbone)
    print(model)

    train_dataset = RetinopathyDataset('/content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/train.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/train/', transform_train)
    val_dataset = RetinopathyDataset('/content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/val.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/val/', transform_test)
    test_dataset = RetinopathyDataset('/content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/', transform_test, test=True)


    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    criterion = nn.CrossEntropyLoss()
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = model.to(device)

    optimizer = torch.optim.Adam(params=model.parameters(), lr=learning_rate)
    lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)


    pretrained_checkpoint = '/content/drive/MyDrive/Colab Notebooks/Deeplearning_project/efficientnet_b0_best_model.pth' # Changed to resnet18.pth
    model.load_state_dict(torch.load(pretrained_checkpoint, map_location=device), strict=False) # Changed strict to False
    # Train model
    def train_model():
        best_kappa = -1
        train_losses, val_losses = [], []
        train_accuracies, val_accuracies = [], []
        for epoch in range(num_epochs):
            model.train()
            running_loss, correct, total = 0.0, 0, 0
            all_preds, all_labels = [], []
            for inputs, labels in tqdm(train_loader, desc=f'Training Epoch {epoch+1}/{num_epochs}'):
                inputs, labels = inputs.to(device), labels.to(device)
                optimizer.zero_grad()
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()

                running_loss += loss.item()
                preds = torch.argmax(outputs, dim=1)
                correct += (preds == labels).sum().item()
                total += labels.size(0)
                all_preds.extend(preds.cpu().numpy())
                all_labels.extend(labels.cpu().numpy())

            lr_scheduler.step()

            train_losses.append(running_loss / len(train_loader))
            train_accuracies.append(correct / total)

            model.eval()
            val_loss, val_correct, val_total = 0.0, 0, 0
            val_preds, val_labels = [], []
            with torch.no_grad():
                for val_inputs, val_labels_batch in val_loader:
                    val_inputs, val_labels_batch = val_inputs.to(device), val_labels_batch.to(device)
                    val_outputs = model(val_inputs)
                    val_loss += criterion(val_outputs, val_labels_batch).item()
                    val_preds_batch = torch.argmax(val_outputs, dim=1)
                    val_correct += (val_preds_batch == val_labels_batch).sum().item()
                    val_total += val_labels_batch.size(0)
                    val_preds.extend(val_preds_batch.cpu().numpy())
                    val_labels.extend(val_labels_batch.cpu().numpy())

            val_losses.append(val_loss / len(val_loader))
            val_accuracies.append(val_correct / val_total)

            kappa = cohen_kappa_score(all_preds, all_labels, weights='quadratic')
            print(f'Epoch {epoch+1} Loss: {running_loss:.4f} Kappa: {kappa:.4f}')

            if kappa > best_kappa:
                best_kappa = kappa
                torch.save(model.state_dict(), 'best_model.pth')

        # Visualization
        plt.figure(figsize=(12, 6))
        plt.plot(range(1, num_epochs + 1), train_losses, label='Training Loss')
        plt.plot(range(1, num_epochs + 1), val_losses, label='Validation Loss')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.title('Loss Curve')
        plt.legend()
        plt.show()

        plt.figure(figsize=(12, 6))
        plt.plot(range(1, num_epochs + 1), train_accuracies, label='Training Accuracy')
        plt.plot(range(1, num_epochs + 1), val_accuracies, label='Validation Accuracy')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.title('Accuracy Curve')
        plt.legend()
        plt.show()

    train_model()

    # Evaluate model
    def evaluate_model():
        model.eval()
        all_preds, all_ids = [], []
        with torch.no_grad():
            for inputs, ids in tqdm(test_loader, desc='Testing'):
                inputs = inputs.to(device)
                outputs = model(inputs)
                preds = torch.argmax(outputs, dim=1)
                all_preds.extend(preds.cpu().numpy())
                all_ids.extend(ids)

        submission = pd.DataFrame({'ID': all_ids, 'Target': all_preds})
        submission.to_csv('/content/drive/MyDrive/Colab Notebooks/dataset/submission_effiecient_1.csv', index=False)
        print('Test predictions saved to submission.csv')

    evaluate_model()
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 142MB/s]
# <ipython-input-2-954eeb4da937>:90: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load('/content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/pretrained_DR_resize/pretrained/efficientnet_b0.pth', map_location='cpu')
# missing keys: ['classifier.1.weight', 'classifier.1.bias']
# unexpected keys: []
# MyModel(
#   (backbone): EfficientNet(
#     (features): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): SiLU(inplace=True)
#       )
#       (1): Sequential(
#         (0): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (2): Conv2dNormActivation(
#               (0): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#         )
#       )
#       (2): Sequential(
#         (0): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#               (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(4, 96, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.0125, mode=row)
#         )
#         (1): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#               (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.025, mode=row)
#         )
#       )
#       (3): Sequential(
#         (0): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#               (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.037500000000000006, mode=row)
#         )
#         (1): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#               (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.05, mode=row)
#         )
#       )
#       (4): Sequential(
#         (0): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#               (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.0625, mode=row)
#         )
#         (1): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#               (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.07500000000000001, mode=row)
#         )
#         (2): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#               (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.08750000000000001, mode=row)
#         )
#       )
#       (5): Sequential(
#         (0): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#               (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.1, mode=row)
#         )
#         (1): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#               (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.1125, mode=row)
#         )
#         (2): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#               (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.125, mode=row)
#         )
#       )
#       (6): Sequential(
#         (0): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#               (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.1375, mode=row)
#         )
#         (1): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#               (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.15000000000000002, mode=row)
#         )
#         (2): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#               (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.1625, mode=row)
#         )
#         (3): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#               (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.17500000000000002, mode=row)
#         )
#       )
#       (7): Sequential(
#         (0): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#               (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.1875, mode=row)
#         )
#       )
#       (8): Conv2dNormActivation(
#         (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): SiLU(inplace=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=1)
#     (classifier): Sequential(
#       (0): Dropout(p=0.2, inplace=True)
#       (1): Linear(in_features=1280, out_features=5, bias=True)
#     )
#   )
# )
# <ipython-input-2-954eeb4da937>:135: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(pretrained_checkpoint, map_location=device), strict=False) # Changed strict to False
# Training Epoch 1/15: 100%|██████████| 38/38 [09:58<00:00, 15.76s/it]
# Epoch 1 Loss: 51.9090 Kappa: 0.5441
# Training Epoch 2/15: 100%|██████████| 38/38 [05:09<00:00,  8.15s/it]
# Epoch 2 Loss: 38.4170 Kappa: 0.7629
# Training Epoch 3/15: 100%|██████████| 38/38 [05:09<00:00,  8.14s/it]
# Epoch 3 Loss: 31.8750 Kappa: 0.8087
# Training Epoch 4/15: 100%|██████████| 38/38 [05:08<00:00,  8.12s/it]
# Epoch 4 Loss: 27.9924 Kappa: 0.8536
# Training Epoch 5/15: 100%|██████████| 38/38 [05:09<00:00,  8.14s/it]
# Epoch 5 Loss: 26.0884 Kappa: 0.8592
# Training Epoch 6/15: 100%|██████████| 38/38 [05:07<00:00,  8.09s/it]
# Epoch 6 Loss: 24.2341 Kappa: 0.8666
# Training Epoch 7/15: 100%|██████████| 38/38 [05:08<00:00,  8.12s/it]
# Epoch 7 Loss: 22.1413 Kappa: 0.8750
# Training Epoch 8/15: 100%|██████████| 38/38 [05:08<00:00,  8.11s/it]
# Epoch 8 Loss: 21.5851 Kappa: 0.8738
# Training Epoch 9/15: 100%|██████████| 38/38 [05:09<00:00,  8.13s/it]
# Epoch 9 Loss: 19.3882 Kappa: 0.9054
# Training Epoch 10/15: 100%|██████████| 38/38 [05:07<00:00,  8.09s/it]
# Epoch 10 Loss: 18.4038 Kappa: 0.9027
# Training Epoch 11/15: 100%|██████████| 38/38 [05:06<00:00,  8.08s/it]
# Epoch 11 Loss: 15.8623 Kappa: 0.9151
# Training Epoch 12/15: 100%|██████████| 38/38 [05:10<00:00,  8.18s/it]
# Epoch 12 Loss: 15.3916 Kappa: 0.9219
# Training Epoch 13/15: 100%|██████████| 38/38 [05:09<00:00,  8.14s/it]
# Epoch 13 Loss: 16.4251 Kappa: 0.9166
# Training Epoch 14/15: 100%|██████████| 38/38 [05:10<00:00,  8.18s/it]
# Epoch 14 Loss: 15.2193 Kappa: 0.9000
# Training Epoch 15/15: 100%|██████████| 38/38 [05:10<00:00,  8.18s/it]
# Epoch 15 Loss: 15.5598 Kappa: 0.9193
# Testing: 100%|██████████| 13/13 [01:53<00:00,  8.73s/it]
# Test predictions saved to submission.csv

# %%
def generate_gradcam(model, image, target_layer, device):
    model.eval()
    # The error was caused by unintentionally adding an extra dimension to the input image.
    # The original line 'image = image.unsqueeze(0).unsqueeze(0).to(device)' was creating a 5-dimensional tensor.
    # Changing it to 'image = image.unsqueeze(0).to(device)' should fix the issue.
    image = image.to(device) # Fixing the extra unsqueeze

    gradients = []
    activations = []

    def forward_hook(module, input, output):
        activations.append(output)

    def backward_hook(module, grad_in, grad_out):
        gradients.append(grad_out[0])

    handle1 = target_layer.register_forward_hook(forward_hook)
    handle2 = target_layer.register_backward_hook(backward_hook)

    output = model(image)
    target_class = torch.argmax(output, dim=1)
    loss = output[0, target_class]
    loss.backward()

    handle1.remove()
    handle2.remove()

    gradients = gradients[0].cpu().data.numpy()[0]
    activations = activations[0].cpu().data.numpy()[0]

    weights = np.mean(gradients, axis=(1, 2))
    cam = np.zeros(activations.shape[1:], dtype=np.float32)

    for i, w in enumerate(weights):
        cam += w * activations[i]

    cam = np.maximum(cam, 0)
    cam = cam - np.min(cam)
    cam = cam / np.max(cam)
    return cam

# %%
# Load and preprocess the image
image_path = '/content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/402/402_l1.jpg'
image = Image.open(image_path).convert('RGB')
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])
#input_tensor = transform(image).unsqueeze(0) # This line was causing the error.
input_tensor = transform(image).unsqueeze(0)  # Adding batch dimension here if needed


# Load your trained model
model = MyModel(num_classes=5, backbone='efficientnet')  # Correctly pass num_classes and backbone
model.load_state_dict(torch.load('/content/best_model.pth'))
model.eval()

# Generate Grad-CAM
# Generate Grad-CAM
# Access layer4 through model.backbone:
target_layer = model.backbone.features[-1]  # Adjust based on your model architecture

# Modified generate_gradcam function call to remove unnecessary unsqueeze:
# Assuming generate_gradcam is defined elsewhere and accepts input_tensor directly
cam = generate_gradcam(model, input_tensor, target_layer, device='cpu')  # Adjust device as needed

# Visualize the result
plt.imshow(image)
plt.imshow(cam, cmap='jet', alpha=0.5)
plt.title("Grad-CAM Visualization")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# <ipython-input-2-954eeb4da937>:90: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load('/content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/pretrained_DR_resize/pretrained/efficientnet_b0.pth', map_location='cpu')
# missing keys: ['classifier.1.weight', 'classifier.1.bias']
# unexpected keys: []
# <ipython-input-5-9fc5046e4e6f>:15: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('/content/best_model.pth'))
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1827: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)

# %%
# !pip install opencv-python
#import cv2 #
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.26.4)

# %%
import cv2
import matplotlib.pyplot as plt

def apply_gradcam(model, img_path, target_layer, output_path):
    transform_test = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])

    image = Image.open(img_path).convert("RGB")
    input_tensor = transform_test(image).unsqueeze(0).to(device)

    # Access layer4 through model.backbone
    cam = GradCAM(model=model, target_layers=[model.backbone.features[-1]])
    grayscale_cam = cam(input_tensor=input_tensor)
    grayscale_cam = grayscale_cam[0, :]

    # Resize grayscale_cam to match the image dimensions
    grayscale_cam = cv2.resize(grayscale_cam, (image.size[0], image.size[1]))

    visualization = show_cam_on_image(np.array(image) / 255.0, grayscale_cam, use_rgb=True)

    # Display the original image
    plt.figure() # Create a new figure
    plt.imshow(image)
    plt.title("Original Image")
    plt.show()

    # Display the Grad-CAM visualization
    plt.figure() # Create another figure for Grad-CAM
    plt.imshow(visualization)
    plt.title("Grad-CAM Visualization")
    plt.show()

    # Save the visualization to the specified path
    plt.imsave(output_path, visualization)
    print(f"Grad-CAM visualization saved to: {output_path}")

# %%
image_path = '/content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/402/402_l1.jpg'
output_path = '/content/drive/MyDrive/Colab Notebooks/dataset/gradcam_visualization_efficient_1.jpg' # Choose your output path
apply_gradcam(model, image_path, target_layer=[model.backbone.features[-1]], output_path=output_path)
# Out:
# Grad-CAM visualization saved to: /content/drive/MyDrive/Colab Notebooks/dataset/gradcam_visualization_efficient_1.jpg

# %%
import pandas as pd

# Read the data into a DataFrame
df= pd.read_csv('/content/drive/MyDrive/Colab Notebooks/dataset/submission_effiecient_1.csv')
 # truncated for readability

# Convert the string data to a DataFrame
#df = pd.read_csv(pd.StringIO(data))

# Clean the ID column by removing the prefix pattern
df['ID'] = df['ID'].str.split('/').str[-1]

# Save the cleaned DataFrame to a new CSV file
df.to_csv('cleaned_submission_efficient.csv', index=False)

# Display the first few rows of the cleaned data
print(df.head())
# Out:
#            ID  Target
# 0  347_l1.jpg       4
# 1  347_l2.jpg       1
# 2  347_r1.jpg       4
# 3  347_r2.jpg       4
# 4  353_l1.jpg       3

# %%
df.duplicated().sum()
# Out:
# 0
