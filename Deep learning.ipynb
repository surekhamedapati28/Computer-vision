# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
# Check if the directory exists
dataset_dir = "/content/drive/MyDrive/Colab Notebooks/dataset"
if not os.path.exists(dataset_dir):
  os.makedirs(dataset_dir)
  print(f"Directory '{dataset_dir}' created successfully.")

# !unzip /content/drive/MyDrive/Colab\ Notebooks/521153S-3005-final-project.zip -d /content/drive/MyDrive/Colab\ Notebooks/dataset
# Out:
# Directory '/content/drive/MyDrive/Colab Notebooks/dataset' created successfully.
# Archive:  /content/drive/MyDrive/Colab Notebooks/521153S-3005-final-project.zip
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/sample_submission.csv
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test.csv
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/347/347_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/347/347_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/347/347_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/347/347_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/353/353_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/353/353_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/353/353_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/353/353_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/354/354_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/354/354_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/354/354_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/354/354_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/366/366_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/366/366_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/366/366_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/366/366_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/368/368_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/368/368_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/368/368_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/368/368_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/371/371_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/371/371_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/371/371_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/371/371_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/377/377_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/377/377_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/377/377_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/377/377_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/383/383_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/383/383_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/383/383_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/383/383_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/384/384_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/384/384_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/384/384_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/384/384_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/386/386_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/386/386_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/386/386_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/386/386_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/387/387_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/387/387_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/387/387_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/387/387_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/389/389_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/389/389_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/389/389_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/389/389_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/391/391_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/391/391_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/391/391_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/391/391_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/396/396_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/396/396_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/396/396_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/396/396_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/398/398_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/398/398_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/398/398_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/398/398_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/403/403_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/403/403_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/403/403_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/403/403_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/408/408_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/408/408_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/408/408_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/408/408_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/409/409_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/409/409_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/409/409_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/409/409_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/411/411_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/411/411_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/411/411_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/411/411_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/412/412_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/412/412_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/412/412_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/412/412_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/417/417_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/417/417_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/417/417_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/417/417_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/418/418_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/418/418_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/418/418_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/418/418_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/419/419_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/419/419_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/419/419_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/419/419_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/420/420_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/420/420_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/420/420_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/420/420_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/421/421_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/421/421_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/421/421_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/421/421_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/423/423_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/423/423_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/423/423_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/423/423_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/424/424_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/424/424_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/424/424_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/424/424_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/425/425_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/425/425_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/425/425_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/425/425_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/426/426_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/426/426_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/426/426_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/426/426_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/427/427_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/427/427_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/427/427_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/427/427_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/428/428_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/428/428_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/428/428_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/428/428_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/429/429_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/429/429_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/429/429_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/429/429_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/432/432_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/432/432_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/432/432_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/432/432_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/434/434_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/434/434_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/434/434_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/434/434_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/435/435_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/435/435_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/435/435_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/435/435_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/436/436_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/436/436_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/436/436_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/436/436_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/437/437_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/437/437_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/437/437_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/437/437_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/438/438_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/438/438_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/438/438_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/438/438_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/439/439_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/439/439_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/439/439_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/439/439_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/440/440_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/440/440_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/440/440_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/440/440_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/441/441_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/441/441_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/441/441_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/441/441_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/442/442_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/442/442_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/442/442_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/442/442_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/443/443_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/443/443_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/443/443_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/443/443_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/444/444_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/444/444_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/444/444_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/444/444_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/445/445_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/445/445_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/445/445_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/445/445_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/446/446_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/446/446_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/446/446_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/446/446_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/447/447_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/447/447_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/447/447_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/447/447_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/448/448_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/448/448_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/448/448_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/448/448_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/449/449_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/449/449_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/449/449_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/449/449_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/450/450_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/450/450_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/450/450_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/450/450_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/451/451_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/451/451_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/451/451_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/451/451_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/452/452_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/452/452_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/452/452_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/452/452_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/453/453_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/453/453_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/453/453_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/453/453_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/454/454_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/454/454_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/454/454_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/454/454_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/455/455_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/455/455_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/455/455_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/455/455_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/456/456_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/456/456_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/456/456_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/456/456_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/457/457_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/457/457_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/457/457_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/457/457_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/458/458_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/458/458_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/458/458_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/458/458_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/459/459_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/459/459_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/459/459_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/459/459_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/460/460_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/460/460_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/460/460_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/460/460_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/461/461_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/461/461_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/461/461_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/461/461_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/462/462_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/462/462_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/462/462_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/462/462_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/463/463_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/463/463_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/463/463_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/463/463_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/464/464_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/464/464_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/464/464_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/464/464_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/465/465_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/465/465_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/465/465_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/465/465_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/466/466_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/466/466_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/466/466_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/466/466_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/467/467_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/467/467_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/467/467_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/467/467_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/468/468_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/468/468_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/468/468_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/468/468_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/469/469_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/469/469_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/469/469_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/469/469_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/470/470_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/470/470_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/470/470_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/470/470_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/471/471_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/471/471_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/471/471_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/471/471_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/472/472_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/472/472_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/472/472_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/472/472_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/473/473_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/473/473_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/473/473_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/473/473_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/474/474_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/474/474_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/474/474_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/474/474_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/475/475_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/475/475_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/475/475_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/475/475_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/476/476_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/476/476_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/476/476_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/476/476_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/477/477_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/477/477_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/477/477_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/477/477_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/478/478_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/478/478_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/478/478_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/478/478_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/479/479_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/479/479_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/479/479_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/479/479_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/480/480_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/480/480_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/480/480_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/480/480_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/481/481_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/481/481_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/481/481_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/481/481_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/482/482_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/482/482_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/482/482_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/482/482_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/483/483_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/483/483_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/483/483_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/483/483_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/484/484_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/484/484_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/484/484_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/484/484_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/485/485_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/485/485_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/485/485_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/485/485_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/486/486_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/486/486_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/486/486_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/486/486_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/487/487_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/487/487_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/487/487_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/487/487_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/488/488_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/488/488_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/488/488_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/488/488_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/489/489_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/489/489_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/489/489_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/489/489_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/490/490_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/490/490_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/490/490_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/490/490_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/491/491_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/491/491_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/491/491_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/491/491_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/492/492_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/492/492_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/492/492_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/492/492_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/493/493_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/493/493_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/493/493_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/493/493_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/494/494_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/494/494_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/494/494_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/494/494_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/495/495_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/495/495_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/495/495_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/495/495_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/496/496_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/496/496_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/496/496_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/496/496_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/497/497_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/497/497_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/497/497_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/497/497_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/498/498_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/498/498_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/498/498_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/498/498_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/499/499_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/499/499_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/499/499_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/499/499_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/500/500_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/500/500_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/500/500_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/500/500_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/train.csv
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/train/1/1_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/train/1/1_l2.jpg
# ...
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/363/363_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/363/363_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/364/364_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/364/364_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/364/364_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/364/364_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/365/365_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/365/365_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/365/365_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/365/365_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/367/367_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/367/367_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/367/367_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/367/367_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/369/369_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/369/369_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/369/369_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/369/369_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/370/370_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/370/370_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/370/370_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/370/370_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/372/372_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/372/372_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/372/372_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/372/372_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/373/373_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/373/373_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/373/373_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/373/373_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/374/374_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/374/374_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/374/374_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/374/374_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/375/375_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/375/375_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/375/375_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/375/375_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/376/376_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/376/376_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/376/376_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/376/376_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/378/378_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/378/378_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/378/378_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/378/378_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/379/379_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/379/379_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/379/379_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/379/379_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/380/380_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/380/380_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/380/380_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/380/380_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/381/381_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/381/381_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/381/381_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/381/381_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/382/382_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/382/382_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/382/382_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/382/382_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/385/385_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/385/385_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/385/385_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/385/385_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/388/388_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/388/388_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/388/388_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/388/388_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/390/390_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/390/390_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/390/390_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/390/390_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/392/392_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/392/392_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/392/392_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/392/392_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/393/393_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/393/393_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/393/393_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/393/393_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/394/394_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/394/394_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/394/394_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/394/394_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/395/395_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/395/395_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/395/395_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/395/395_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/397/397_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/397/397_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/397/397_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/397/397_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/399/399_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/399/399_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/399/399_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/399/399_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/400/400_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/400/400_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/400/400_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/400/400_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/401/401_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/401/401_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/401/401_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/401/401_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/402/402_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/402/402_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/402/402_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/402/402_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/404/404_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/404/404_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/404/404_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/404/404_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/405/405_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/405/405_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/405/405_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/405/405_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/406/406_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/406/406_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/406/406_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/406/406_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/407/407_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/407/407_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/407/407_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/407/407_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/410/410_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/410/410_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/410/410_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/410/410_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/413/413_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/413/413_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/413/413_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/413/413_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/414/414_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/414/414_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/414/414_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/414/414_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/415/415_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/415/415_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/415/415_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/415/415_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/416/416_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/416/416_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/416/416_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/416/416_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/422/422_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/422/422_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/422/422_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/422/422_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/430/430_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/430/430_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/430/430_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/430/430_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/431/431_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/431/431_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/431/431_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/431/431_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/433/433_l1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/433/433_l2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/433/433_r1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/DeepDRiD/val/433/433_r2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/release/template_code.py

# %%
import copy
import os
import random
import sys

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image
from sklearn.metrics import cohen_kappa_score, precision_score, recall_score, accuracy_score
from torch.utils.data import Dataset, DataLoader
from torchvision import models, transforms
from torchvision.transforms.functional import to_pil_image
from tqdm import tqdm

# Hyper Parameters
batch_size = 64
num_classes = 5  # 5 DR levels
learning_rate = 5e-5
num_epochs = 20  # Reduced epochs for faster execution

class RetinopathyDataset(Dataset):
    def __init__(self, ann_file, image_dir, transform=None, mode='single', test=False):
        self.ann_file = ann_file
        self.image_dir = image_dir
        self.transform = transform
        self.test = test
        self.mode = mode

        if self.mode == 'single':
            self.data = self.load_data()
        else:
            self.data = self.load_data_dual()

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        if self.mode == 'single':
            return self.get_item(index)
        else:
            return self.get_item_dual(index)

    def load_data(self):
        df = pd.read_csv(self.ann_file)
        data = []
        for _, row in df.iterrows():
            file_info = dict()
            file_info['img_path'] = os.path.join(self.image_dir, row['img_path'])
            if not self.test:
                file_info['dr_level'] = int(row['patient_DR_Level'])
            data.append(file_info)
        return data

    def get_item(self, index):
        data = self.data[index]
        img = Image.open(data['img_path']).convert('RGB')
        if self.transform:
            img = self.transform(img)

        if not self.test:
            label = torch.tensor(data['dr_level'], dtype=torch.int64)
            return img, label
        else:
            return img

    def load_data_dual(self):
        df = pd.read_csv(self.ann_file)
        df['prefix'] = df['image_id'].str.split('_').str[0]  # The patient id of each image
        df['suffix'] = df['image_id'].str.split('_').str[1].str[0]  # The left or right eye
        grouped = df.groupby(['prefix', 'suffix'])
        data = []
        for (prefix, suffix), group in grouped:
            file_info = dict()
            file_info['img_path1'] = os.path.join(self.image_dir, group.iloc[0]['img_path'])
            file_info['img_path2'] = os.path.join(self.image_dir, group.iloc[1]['img_path'])
            if not self.test:
                file_info['dr_level'] = int(group.iloc[0]['patient_DR_Level'])
            data.append(file_info)
        return data

    def get_item_dual(self, index):
        data = self.data[index]
        img1 = Image.open(data['img_path1']).convert('RGB')
        img2 = Image.open(data['img_path2']).convert('RGB')

        if self.transform:
            img1 = self.transform(img1)
            img2 = self.transform(img2)

        if not self.test:
            label = torch.tensor(data['dr_level'], dtype=torch.int64)
            return [img1, img2], label
        else:
            return [img1, img2]

transform_train = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.RandomCrop((210, 210)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5),
    transforms.ColorJitter(brightness=(0.1, 0.9)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

transform_test = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

def train_model(model, train_loader, val_loader, device, criterion, optimizer, lr_scheduler, num_epochs=10,
                checkpoint_path='/content/drive/MyDrive/Colab Notebooks/dataset/model1.pth'):
    scaler = torch.cuda.amp.GradScaler()  # Mixed precision training
    best_model = model.state_dict()
    best_epoch = None
    best_val_kappa = -1.0

    for epoch in range(1, num_epochs + 1):
        print(f'\nEpoch {epoch}/{num_epochs}')
        running_loss = []
        all_preds = []
        all_labels = []

        model.train()
        with tqdm(total=len(train_loader), desc=f'Training', unit='batch', file=sys.stdout) as pbar:
            for images, labels in train_loader:
                images = images.to(device)
                labels = labels.to(device)

                optimizer.zero_grad()
                with torch.cuda.amp.autocast():
                    outputs = model(images)
                    loss = criterion(outputs, labels.long())

                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()

                preds = torch.argmax(outputs, 1)
                all_preds.extend(preds.cpu().numpy())
                all_labels.extend(labels.cpu().numpy())

                running_loss.append(loss.item())
                pbar.set_postfix({'Loss': f'{loss.item():.4f}'})
                pbar.update(1)

        lr_scheduler.step()
        epoch_loss = sum(running_loss) / len(running_loss)
        train_kappa = cohen_kappa_score(all_labels, all_preds, weights='quadratic')
        print(f'[Train] Kappa: {train_kappa:.4f}, Loss: {epoch_loss:.4f}')

        val_metrics = evaluate_model(model, val_loader, device)
        val_kappa = val_metrics['kappa']
        print(f'[Val] Kappa: {val_kappa:.4f}')

        if val_kappa > best_val_kappa:
            best_val_kappa = val_kappa
            best_epoch = epoch
            best_model = model.state_dict()
            torch.save(best_model, checkpoint_path)

    print(f'[Val] Best kappa: {best_val_kappa:.4f}, Epoch {best_epoch}')
    return model

def evaluate_model(model, test_loader, device):
    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            preds = torch.argmax(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    kappa = cohen_kappa_score(all_labels, all_preds, weights='quadratic')
    return {'kappa': kappa}

def create_submission(model, test_loader, device, output_file='/content/drive/MyDrive/Colab Notebooks/dataset/submission1.csv'):
    model.eval()
    results = []
    image_ids = []

    with torch.no_grad():
        for i, images in enumerate(test_loader):
            images = images.to(device)
            outputs = model(images)
            preds = torch.argmax(outputs, 1).cpu().numpy()
            results.extend(preds)
            # Get image IDs for the current batch
            batch_image_ids = [test_loader.dataset.data[i * test_loader.batch_size + j]['img_path'] for j in range(len(images))]
            image_ids.extend(batch_image_ids)

    submission = pd.DataFrame({"ID": image_ids, "TARGET": results})
    submission.to_csv(output_file, index=False)
    print(f'Submission saved to {output_file}')


class MyModel(nn.Module):
    def __init__(self, num_classes=5):
        super().__init__()
        self.backbone = models.resnet18(pretrained=True)
        self.backbone.fc = nn.Linear(self.backbone.fc.in_features, num_classes)

    def forward(self, x):
        return self.backbone(x)

if __name__ == '__main__':
    train_dataset = RetinopathyDataset('/content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/train.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/train/', transform_train)
    val_dataset = RetinopathyDataset('/content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/val.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/val/', transform_test)
    test_dataset = RetinopathyDataset('/content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test.csv', '/content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test/', transform_test, test=True)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = MyModel(num_classes=num_classes).to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)

    model = train_model(model, train_loader, val_loader, device, criterion, optimizer, lr_scheduler, num_epochs=num_epochs)
    create_submission(model, test_loader, device)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 159MB/s]
# <ipython-input-2-ba820728c23e>:116: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()  # Mixed precision training
# /usr/local/lib/python3.10/dist-packages/torch/amp/grad_scaler.py:132: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn(
# Epoch 1/20
# Training:   0%|          | 0/19 [00:00<?, ?batch/s]
# <ipython-input-2-ba820728c23e>:134: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# Training: 100%|██████████| 19/19 [18:59<00:00, 59.95s/batch, Loss=0.8998]
# [Train] Kappa: 0.5104, Loss: 1.3236
# [Val] Kappa: 0.6919
#
# Epoch 2/20
# Training:   0%|          | 0/19 [00:00<?, ?batch/s]
# <ipython-input-2-ba820728c23e>:134: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# Training: 100%|██████████| 19/19 [05:30<00:00, 17.38s/batch, Loss=0.9296]
# [Train] Kappa: 0.7251, Loss: 0.9764
# [Val] Kappa: 0.7204
#
# Epoch 3/20
# Training:   0%|          | 0/19 [00:00<?, ?batch/s]
# <ipython-input-2-ba820728c23e>:134: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# Training: 100%|██████████| 19/19 [05:31<00:00, 17.44s/batch, Loss=0.7430]
# [Train] Kappa: 0.7893, Loss: 0.8577
# [Val] Kappa: 0.7432
#
# Epoch 4/20
# Training:   0%|          | 0/19 [00:00<?, ?batch/s]
# <ipython-input-2-ba820728c23e>:134: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# Training: 100%|██████████| 19/19 [05:29<00:00, 17.32s/batch, Loss=0.7347]
# [Train] Kappa: 0.8111, Loss: 0.7716
# [Val] Kappa: 0.7052
#
# Epoch 5/20
# Training:   0%|          | 0/19 [00:00<?, ?batch/s]
# <ipython-input-2-ba820728c23e>:134: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# Training: 100%|██████████| 19/19 [05:29<00:00, 17.32s/batch, Loss=0.7015]
# [Train] Kappa: 0.8309, Loss: 0.6961
# [Val] Kappa: 0.7199
#
# Epoch 6/20
# Training:   0%|          | 0/19 [00:00<?, ?batch/s]
# <ipython-input-2-ba820728c23e>:134: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# Training: 100%|██████████| 19/19 [05:29<00:00, 17.33s/batch, Loss=0.6149]
# [Train] Kappa: 0.8360, Loss: 0.6610
# [Val] Kappa: 0.7224
#
# Epoch 7/20
# Training:   0%|          | 0/19 [00:00<?, ?batch/s]
# <ipython-input-2-ba820728c23e>:134: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# Training: 100%|██████████| 19/19 [05:29<00:00, 17.34s/batch, Loss=0.9483]
# [Train] Kappa: 0.8458, Loss: 0.6470
# [Val] Kappa: 0.7262
#
# Epoch 8/20
# Training:   0%|          | 0/19 [00:00<?, ?batch/s]
# <ipython-input-2-ba820728c23e>:134: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# Training: 100%|██████████| 19/19 [05:29<00:00, 17.34s/batch, Loss=0.5078]
# [Train] Kappa: 0.8502, Loss: 0.6133
# [Val] Kappa: 0.7091
#
# Epoch 9/20
# Training:   0%|          | 0/19 [00:00<?, ?batch/s]
# <ipython-input-2-ba820728c23e>:134: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# Training: 100%|██████████| 19/19 [05:27<00:00, 17.23s/batch, Loss=0.8145]
# [Train] Kappa: 0.8514, Loss: 0.6230
# [Val] Kappa: 0.7184
#
# Epoch 10/20
# Training:   0%|          | 0/19 [00:00<?, ?batch/s]
# <ipython-input-2-ba820728c23e>:134: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# Training: 100%|██████████| 19/19 [05:27<00:00, 17.25s/batch, Loss=0.5726]
# [Train] Kappa: 0.8555, Loss: 0.6037
# [Val] Kappa: 0.7277
#
# Epoch 11/20
# Training:   0%|          | 0/19 [00:00<?, ?batch/s]
# <ipython-input-2-ba820728c23e>:134: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# Training: 100%|██████████| 19/19 [05:27<00:00, 17.21s/batch, Loss=0.4912]
# [Train] Kappa: 0.8701, Loss: 0.6111
# [Val] Kappa: 0.7313
#
# Epoch 12/20
# Training:   0%|          | 0/19 [00:00<?, ?batch/s]
# <ipython-input-2-ba820728c23e>:134: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# Training: 100%|██████████| 19/19 [05:29<00:00, 17.32s/batch, Loss=0.6337]
# [Train] Kappa: 0.8564, Loss: 0.6163
# [Val] Kappa: 0.7295
#
# Epoch 13/20
# Training:   0%|          | 0/19 [00:00<?, ?batch/s]
# <ipython-input-2-ba820728c23e>:134: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# Training: 100%|██████████| 19/19 [05:27<00:00, 17.22s/batch, Loss=0.6639]
# [Train] Kappa: 0.8671, Loss: 0.6078
# [Val] Kappa: 0.7291
#
# Epoch 14/20
# Training:   0%|          | 0/19 [00:00<?, ?batch/s]
# <ipython-input-2-ba820728c23e>:134: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# Training: 100%|██████████| 19/19 [05:29<00:00, 17.37s/batch, Loss=0.5672]
# [Train] Kappa: 0.8545, Loss: 0.5914
# [Val] Kappa: 0.7271
#
# Epoch 15/20
# Training:   0%|          | 0/19 [00:00<?, ?batch/s]
# <ipython-input-2-ba820728c23e>:134: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# Training: 100%|██████████| 19/19 [05:29<00:00, 17.32s/batch, Loss=0.6841]
# [Train] Kappa: 0.8777, Loss: 0.6019
# [Val] Kappa: 0.7288
#
# Epoch 16/20
# Training:   0%|          | 0/19 [00:00<?, ?batch/s]
# <ipython-input-2-ba820728c23e>:134: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# Training: 100%|██████████| 19/19 [05:26<00:00, 17.18s/batch, Loss=0.6957]
# [Train] Kappa: 0.8641, Loss: 0.5883
# [Val] Kappa: 0.7408
#
# Epoch 17/20
# Training:   0%|          | 0/19 [00:00<?, ?batch/s]
# <ipython-input-2-ba820728c23e>:134: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# Training: 100%|██████████| 19/19 [05:30<00:00, 17.39s/batch, Loss=0.7845]
# [Train] Kappa: 0.8590, Loss: 0.6132
# [Val] Kappa: 0.7274
#
# Epoch 18/20
# Training:   0%|          | 0/19 [00:00<?, ?batch/s]
# <ipython-input-2-ba820728c23e>:134: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# Training: 100%|██████████| 19/19 [05:26<00:00, 17.17s/batch, Loss=0.5808]
# [Train] Kappa: 0.8740, Loss: 0.6063
# [Val] Kappa: 0.7323
#
# Epoch 19/20
# Training:   0%|          | 0/19 [00:00<?, ?batch/s]
# <ipython-input-2-ba820728c23e>:134: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# Training: 100%|██████████| 19/19 [05:35<00:00, 17.66s/batch, Loss=0.5106]
# [Train] Kappa: 0.8580, Loss: 0.5961
# [Val] Kappa: 0.7267
#
# Epoch 20/20
# Training:   0%|          | 0/19 [00:00<?, ?batch/s]
# <ipython-input-2-ba820728c23e>:134: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# Training: 100%|██████████| 19/19 [05:33<00:00, 17.54s/batch, Loss=0.5834]
# [Train] Kappa: 0.8629, Loss: 0.6035
# [Val] Kappa: 0.7313
# [Val] Best kappa: 0.7432, Epoch 3
# Submission saved to /content/drive/MyDrive/Colab Notebooks/dataset/submission1.csv

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD"
# Out:
# sample_submission.csv  test  test.csv  train  train.csv  val  val.csv
