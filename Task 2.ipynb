# %%
# prompt: cannot create extraction directory: /content/drive/MyDrive/Colab\ Notebooks/dataset
#            No such file or directory

import os

# Create the directory if it doesn't exist
directory_path = '/content/drive/MyDrive/Colab Notebooks/dataset/archive.zip'
if not os.path.exists(directory_path):
    os.makedirs(directory_path)
    print(f"Directory '{directory_path}' created successfully.")
else:
    print(f"Directory '{directory_path}' already exists.")
# Out:
# Directory '/content/drive/MyDrive/Colab Notebooks/dataset/archive.zip' already exists.

# %%
import os
# Check if the directory exists
dataset_dir = "/content/drive/MyDrive/Colab Notebooks/dataset/archive.zip"
# !unzip '/content/drive/MyDrive/Colab Notebooks/dataset/archive.zip' -d '/content/drive/MyDrive/Colab Notebooks/dataset/'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24064_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24064_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24073_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24073_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24074_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24074_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24075_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24075_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24076_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24076_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2407_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2407_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24083_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24083_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24086_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24086_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24087_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24087_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24088_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24088_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24089_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24089_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2408_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2408_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24090_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24090_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24092_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24092_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24094_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24094_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24095_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24095_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/240_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/240_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24102_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24102_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24104_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24104_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24106_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24106_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24107_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24107_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24111_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24111_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24115_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24115_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24117_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24117_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24119_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24119_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24126_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24126_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24127_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24127_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24130_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24130_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24134_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24134_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24137_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24137_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24138_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24138_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2413_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2413_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24140_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24140_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24141_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24141_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24142_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24142_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24144_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24144_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24147_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24147_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24148_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24148_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24150_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24150_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24152_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24152_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24155_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24155_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24156_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24156_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24157_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24157_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24159_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24159_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24163_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24163_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24166_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24166_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24168_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24168_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24170_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24170_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24171_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24171_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24173_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24173_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24179_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24179_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24186_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24186_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2418_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2418_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24191_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24191_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24193_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24193_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24197_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24197_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24199_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24199_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/241_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/241_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24201_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24201_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24202_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24202_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24203_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24203_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24206_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24206_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24207_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24207_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24208_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24208_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24209_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24209_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24210_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24210_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24213_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24213_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24214_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24214_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24215_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24215_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24218_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24218_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2421_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2421_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24221_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24221_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24222_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24222_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24224_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24224_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24227_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24227_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24230_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24230_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24232_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24232_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24233_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24233_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24234_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24234_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24237_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24237_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24238_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24238_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2423_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2423_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24241_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24241_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24242_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24242_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24243_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24243_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24246_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24246_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24247_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24247_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24249_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24249_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2424_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2424_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24252_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24252_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24256_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24256_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24257_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24257_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24259_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24259_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2425_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2425_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24261_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24261_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24262_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24262_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24263_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24263_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24266_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24266_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24268_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24268_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24270_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24270_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24273_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24273_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24279_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24279_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24284_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24284_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24292_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24292_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24297_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24297_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24298_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24298_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24299_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24299_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/242_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/242_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24301_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24301_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24302_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24302_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24304_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24304_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24305_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24305_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2430_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2430_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24310_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24310_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24314_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24314_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24317_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24317_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24318_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24318_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24325_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24325_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24327_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24327_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24328_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24328_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2432_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2432_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24334_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24334_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24335_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24335_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24336_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24336_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24339_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24339_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2433_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2433_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24340_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24340_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24341_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24341_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24343_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24343_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24346_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24346_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24353_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24353_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24355_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24355_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2435_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2435_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24367_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24367_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24368_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24368_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24369_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24369_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2436_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2436_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24378_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24378_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2437_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2437_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24381_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24381_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24384_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24384_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24386_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24386_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24387_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24387_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24391_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24391_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24392_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24392_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24393_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24393_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24394_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24394_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24397_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24397_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24398_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24398_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2439_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2439_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24401_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24401_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24402_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24402_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24403_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24403_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24405_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24405_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24406_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24406_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24408_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24408_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24410_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24410_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24412_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24412_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24416_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24416_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24418_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24418_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24419_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24419_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2441_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2441_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24420_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24420_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24421_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24421_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24422_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24422_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24424_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24424_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24425_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24425_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24437_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24437_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24438_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24438_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2443_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2443_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24446_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24446_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24447_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24447_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24449_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24449_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24450_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24450_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24453_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24453_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24457_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24457_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24460_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24460_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24461_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24461_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24464_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24464_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24468_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24468_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24469_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24469_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24472_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24472_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24474_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24474_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24476_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24476_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24478_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24478_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2447_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2447_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24480_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24480_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24484_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24484_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24485_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24485_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24488_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24488_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2448_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2448_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24490_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24490_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24491_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24491_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24492_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24492_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/244_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/244_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/24503_left.jpeg
# ...
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29636_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29636_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29638_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29638_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29639_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29639_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2963_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2963_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29640_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29640_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29642_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29642_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29645_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29645_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29646_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29646_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29647_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29647_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29648_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29648_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2964_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2964_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29650_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29650_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29652_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29652_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29654_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29654_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29656_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29656_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29658_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29658_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2965_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2965_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29660_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29660_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29661_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29661_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29666_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29666_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29669_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29669_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2966_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2966_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29670_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29670_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29671_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29671_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29672_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29672_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29673_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29673_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29674_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29674_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29676_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29676_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29678_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29678_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29679_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29679_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29682_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29682_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29684_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29684_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29686_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29686_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29688_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29688_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29690_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29690_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29696_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29696_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2969_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2969_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29700_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29700_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29702_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29702_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29703_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29703_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29704_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29704_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29705_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29705_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29706_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29706_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29708_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29708_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29709_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29709_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2970_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2970_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29710_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29710_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29711_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29711_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29712_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29712_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29713_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29713_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29722_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29722_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29723_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29723_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29726_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29726_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29727_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29727_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2972_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2972_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29730_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29730_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29732_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29732_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29734_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29734_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29737_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29737_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29739_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29739_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2973_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/2973_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29740_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29740_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29741_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29741_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29744_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29744_right.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29746_left.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/resized_train_cropped/resized_train_cropped/29746_right.jpeg

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import cohen_kappa_score
from torchvision import models, transforms
from torch.utils.data import DataLoader, Dataset
import torch
import torch.nn as nn
import torch.optim as optim
from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.image import show_cam_on_image
from PIL import Image

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# === DATASET PREPARATION ===
class DRDataset(Dataset):
    def __init__(self, csv_file, root_dir, transform=None):
        self.data = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        img_name = os.path.join(self.root_dir, self.data.iloc[idx, 0])
        image = Image.open(img_name).convert("RGB")
        label = self.data.iloc[idx, 1]

        if self.transform:
            image = self.transform(image)

        return image, label

# Transforms
transform = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
}

# Load datasets
dataset_train = DRDataset(csv_file='train_labels.csv', root_dir='train_images', transform=transform['train'])
dataset_val = DRDataset(csv_file='val_labels.csv', root_dir='val_images', transform=transform['val'])

def load_model(model_name):
    if model_name == "ResNet18":
        model = models.resnet18(pretrained=True)
    elif model_name == "ResNet34":
        model = models.resnet34(pretrained=True)
    elif model_name == "VGG":
        model = models.vgg16(pretrained=True)
    elif model_name == "EfficientNet":
        model = models.efficientnet_b0(pretrained=True)
    else:
        raise ValueError("Unsupported model name")

    num_features = model.fc.in_features if hasattr(model, 'fc') else model.classifier[-1].in_features
    if hasattr(model, 'fc'):
        model.fc = nn.Linear(num_features, 5)
    else:
        model.classifier[-1] = nn.Linear(num_features, 5)

    return model

# Select model
model_name = "ResNet18"  # Change this to "ResNet34", "VGG", or "EfficientNet" as needed
model = load_model(model_name)
model = model.to(device)

train_loader = DataLoader(dataset_train, batch_size=32, shuffle=True)
val_loader = DataLoader(dataset_val, batch_size=32, shuffle=False)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# === TRAINING LOOP ===
def train_model(model, criterion, optimizer, train_loader, val_loader, num_epochs=10):
    train_losses, val_losses = [], []
    best_kappa = -1

    for epoch in range(num_epochs):
        model.train()
        train_loss = 0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()

        train_loss /= len(train_loader)
        train_losses.append(train_loss)

        # Validation
        model.eval()
        val_loss = 0
        all_preds, all_labels = [], []

        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                val_loss += loss.item()
                preds = torch.argmax(outputs, dim=1)
                all_preds.extend(preds.cpu().numpy())
                all_labels.extend(labels.cpu().numpy())

        val_loss /= len(val_loader)
        val_losses.append(val_loss)

        # Cohen Kappa
        kappa = cohen_kappa_score(all_preds, all_labels, weights='quadratic')
        print(f"Epoch {epoch + 1}/{num_epochs}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, Kappa: {kappa:.4f}")

        # Save best model
        if kappa > best_kappa:
            best_kappa = kappa
            torch.save(model.state_dict(), f'best_model_{model_name}.pth')

    return train_losses, val_losses

train_losses, val_losses = train_model(model, criterion, optimizer, train_loader, val_loader, num_epochs=10)

# === FINE-TUNE ON DEEPDRiD DATASET ===
# Load DeepDRiD dataset
dataset_deepdrid_train = DRDataset(csv_file='/content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/train.csv', root_dir='/content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/train', transform=transform['train'])
dataset_deepdrid_val = DRDataset(csv_file='/content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/val.csv', root_dir='/content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/val', transform=transform['val'])

train_loader_deepdrid = DataLoader(dataset_deepdrid_train, batch_size=32, shuffle=True)
val_loader_deepdrid = DataLoader(dataset_deepdrid_val, batch_size=32, shuffle=False)

# Load pretrained model from Kaggle DR Resized training
model.load_state_dict(torch.load(f'best_model_{model_name}.pth'))

# Fine-tune on DeepDRiD
def fine_tune_on_deepdrid(model, criterion, optimizer, train_loader, val_loader, num_epochs=10):
    train_losses, val_losses = [], []
    best_kappa = -1

    for epoch in range(num_epochs):
        model.train()
        train_loss = 0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()

        train_loss /= len(train_loader)
        train_losses.append(train_loss)

        # Validation
        model.eval()
        val_loss = 0
        all_preds, all_labels = [], []

        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                val_loss += loss.item()
                preds = torch.argmax(outputs, dim=1)
                all_preds.extend(preds.cpu().numpy())
                all_labels.extend(labels.cpu().numpy())

        val_loss /= len(val_loader)
        val_losses.append(val_loss)

        # Cohen Kappa
        kappa = cohen_kappa_score(all_preds, all_labels, weights='quadratic')
        print(f"Epoch {epoch + 1}/{num_epochs} (DeepDRiD), Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, Kappa: {kappa:.4f}")

        # Save best model
        if kappa > best_kappa:
            best_kappa = kappa
            torch.save(model.state_dict(), f'best_model_deepdrid_{model_name}.pth')

    return train_losses, val_losses

train_losses_deepdrid, val_losses_deepdrid = fine_tune_on_deepdrid(model, criterion, optimizer, train_loader_deepdrid, val_loader_deepdrid, num_epochs=10)

# === VISUALIZATIONS ===
plt.figure()
plt.plot(train_losses_deepdrid, label='DeepDRiD Training Loss')
plt.plot(val_losses_deepdrid, label='DeepDRiD Validation Loss')
plt.legend()
plt.title('Losses over Epochs (DeepDRiD)')
plt.show()

# === TEST SUBMISSION ===
def create_submission_file(model, test_csv, test_images_dir, output_csv):
    model.eval()
    test_data = pd.read_csv(test_csv)
    predictions = []

    transform_test = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])

    with torch.no_grad():
        for idx, row in test_data.iterrows():
            img_path = os.path.join(test_images_dir, row['ID'])
            image = Image.open(img_path).convert("RGB")
            input_tensor = transform_test(image).unsqueeze(0).to(device)
            output = model(input_tensor)
            pred = torch.argmax(output, dim=1).item()
            predictions.append(pred)

    test_data['Prediction'] = predictions
    test_data.to_csv(output_csv, index=False)
    print(f"Submission file saved to {output_csv}")

# Example usage:
create_submission_file(model, test_csv='/content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test.csv', test_images_dir='/content/drive/MyDrive/Colab Notebooks/dataset/521153S-3005-final-project/DeepDRiD/test', output_csv='/content/drive/MyDrive/Colab Notebooks/dataset/submission_hybrid.csv')

# %%
# === GRADCAM ===
def apply_gradcam(model, img_path, target_layer):
    transform_test = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])

    image = Image.open(img_path).convert("RGB")
    input_tensor = transform_test(image).unsqueeze(0).to(device)

    cam = GradCAM(model=model, target_layers=target_layer)
    grayscale_cam = cam(input_tensor=input_tensor, target_category=None)
    grayscale_cam = grayscale_cam[0, :]

    visualization = show_cam_on_image(np.array(image) / 255.0, grayscale_cam, use_rgb=True)
    plt.imshow(visualization)
    plt.show()

# %%
example_image, _ = train_dataset[0]

# %%
# Example usage:
model.load_state_dict(torch.load(f'best_model_deepdrid_{model_name}.pth'))
apply_gradcam(model, 'example_image.jpg', target_layer=[model.layer4[-1]])
